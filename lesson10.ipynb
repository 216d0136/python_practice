# %% [markdown]
# <a href="https://colab.research.google.com/github/216d0136/python_practice/blob/master/lesson10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install icrawler

from icrawler.builtin import BingImageCrawler

# 猫の画像を100枚取得
crawler = BingImageCrawler(storage={"root_dir": "cat"})
crawler.crawl(keyword="猫", max_num=100)


# 犬の画像を100枚取得
# crawler = GoogleImageCrawler(storage={"root_dir": "dogs"})
# crawler.crawl(keyword="犬", max_num=100)
from icrawler.builtin import BingImageCrawler

# 猫の画像を100枚取得
crawler = BingImageCrawler(storage={"root_dir": "dog"})
crawler.crawl(keyword="犬", max_num=100)

# 猫の画像を表示
from IPython.display import Image,display_jpeg
display_jpeg(Image("./cat/000001.jpg"))


from PIL import Image
import os, glob
import numpy as np
from PIL import ImageFile
# IOError: image file is truncated (0 bytes not processed)回避のため
ImageFile.LOAD_TRUNCATED_IMAGES = True

classes = ["dog", "cat"]
num_classes = len(classes)
image_size = 64
num_testdata = 25

X_train = []
X_test  = []
y_train = []
y_test  = []

for index, classlabel in enumerate(classes):
    photos_dir = "./" + classlabel
    files = glob.glob(photos_dir + "/*.jpg")
    for i, file in enumerate(files):
        image = Image.open(file)
        image = image.convert("RGB")
        image = image.resize((image_size, image_size))
        data = np.asarray(image)
        if i < num_testdata:
            X_test.append(data)
            y_test.append(index)
        else:

            # angleに代入される値
            # -20
            # -15
            # -10
            #  -5
            # 0
            # 5
            # 10
            # 15
            for angle in range(-20, 20, 5):

                img_r = image.rotate(angle)
                data = np.asarray(img_r)
                X_train.append(data)
                y_train.append(index)
                # FLIP_LEFT_RIGHT　は 左右反転
                img_trains = img_r.transpose(Image.FLIP_LEFT_RIGHT)
                data = np.asarray(img_trains)
                X_train.append(data)
                y_train.append(index)

X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

xy = (X_train, X_test, y_train, y_test)
np.save("./dog_cat.npy", xy)


from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.optimizers import RMSprop
from keras.utils import np_utils
import keras
import numpy as np

classes = ["dog", "cat"]
num_classes = len(classes)
image_size = 64

"""
データを読み込む関数
"""
def load_data():
    X_train, X_test, y_train, y_test = np.load("./dog_cat.npy", allow_pickle=True)
    # 入力データの各画素値を0-1の範囲で正規化(学習コストを下げるため)
    X_train = X_train.astype("float") / 255
    X_test  = X_test.astype("float") / 255
    # to_categorical()にてラベルをone hot vector化
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test  = np_utils.to_categorical(y_test, num_classes)

    return X_train, y_train, X_test, y_test

"""
モデルを学習する関数
"""
def train(X, y, X_test, y_test):
    model = Sequential()

    # Xは(1200, 64, 64, 3)
    # X.shape[1:]とすることで、(64, 64, 3)となり、入力にすることが可能です。
    model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.1))

    model.add(Conv2D(64,(3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.45))
    model.add(Dense(2))
    model.add(Activation('softmax'))

    # https://keras.io/ja/optimizers/
    # 今回は、最適化アルゴリズムにRMSpropを利用
    opt = RMSprop(lr=0.00005, decay=1e-6)
    # https://keras.io/ja/models/sequential/
    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    model.fit(X, y, batch_size=28, epochs=40)
    # HDF5ファイルにKerasのモデルを保存
    model.save('./cnn.h5')

    return model

"""
メイン関数
データの読み込みとモデルの学習を行います。
"""
def main():
    # データの読み込み
    X_train, y_train, X_test, y_test = load_data()

    # モデルの学習
    model = train(X_train, y_train, X_test, y_test)

main()

import keras
import sys, os
import numpy as np
from keras.models import load_model

imsize = (64, 64)

"""
dog1.jpgというファイル名の画像をGoogle Colab上にアップロードする方法は2通りあります。
1つが、下記のコードを実行し画像をアップロードする方法
from google.colab import files
uploaded = files.upload()
2つが、Colab左メニューの>アイコンを押して、目次、コード スニペット、ファイル
の3つ表示されるますが、右のファイルタブから画像をアップロードする方法です。
このファイルタブをクリックするとアップロードと更新の2つがありますが、
アップロードを押すと画像をアップロードすることが可能です。
"""

testpic     = "./kitty-551554_960_720.jpg"
keras_param = "./cnn.h5"

def load_image(path):
    img = Image.open(path)
    img = img.convert('RGB')
    # 学習時に、(64, 64, 3)で学習したので、画像の縦・横は今回 変数imsizeの(64, 64)にリサイズします。
    img = img.resize(imsize)
    # 画像データをnumpy配列の形式に変更
    img = np.asarray(img)
    img = img / 255.0
    return img

model = load_model(keras_param)
img = load_image(testpic)
prd = model.predict(np.array([img]))
print(prd) # 精度の表示
prelabel = np.argmax(prd, axis=1)
if prelabel == 0:
    print(">>> 犬")
elif prelabel == 1:
    print(">>> 猫")
# Out:
# Requirement already satisfied: icrawler in /usr/local/lib/python3.6/dist-packages (0.6.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from icrawler) (1.15.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.6.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from icrawler) (7.0.0)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.6/dist-packages (from icrawler) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from icrawler) (4.2.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.9.1->icrawler) (3.0.4)
# 2020-09-12 10:37:33,490 - INFO - icrawler.crawler - start crawling...
# 2020-09-12 10:37:33,491 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-09-12 10:37:33,498 - INFO - feeder - thread feeder-001 exit
# 2020-09-12 10:37:33,500 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-09-12 10:37:33,507 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-09-12 10:37:33,762 - INFO - parser - parsing result page https://www.bing.com/images/async?q=猫&first=0
# 2020-09-12 10:37:33,778 - INFO - downloader - skip downloading file 000001.jpg
# 2020-09-12 10:37:33,779 - INFO - downloader - skip downloading file 000002.jpg
# 2020-09-12 10:37:33,780 - INFO - downloader - skip downloading file 000003.jpg
# 2020-09-12 10:37:33,782 - INFO - downloader - skip downloading file 000004.jpg
# 2020-09-12 10:37:33,783 - INFO - downloader - skip downloading file 000005.jpg
# 2020-09-12 10:37:33,785 - INFO - downloader - skip downloading file 000006.jpg
# 2020-09-12 10:37:33,786 - INFO - downloader - skip downloading file 000007.jpg
# 2020-09-12 10:37:33,787 - INFO - downloader - skip downloading file 000008.jpg
# 2020-09-12 10:37:33,788 - INFO - downloader - skip downloading file 000009.jpg
# 2020-09-12 10:37:33,789 - INFO - downloader - skip downloading file 000010.jpg
# 2020-09-12 10:37:33,792 - INFO - downloader - skip downloading file 000011.jpg
# 2020-09-12 10:37:33,793 - INFO - downloader - skip downloading file 000012.jpg
# 2020-09-12 10:37:33,794 - INFO - downloader - skip downloading file 000013.jpg
# 2020-09-12 10:37:33,796 - INFO - downloader - skip downloading file 000014.jpg
# 2020-09-12 10:37:33,797 - INFO - downloader - skip downloading file 000015.jpg
# 2020-09-12 10:37:33,798 - INFO - downloader - skip downloading file 000016.jpg
# 2020-09-12 10:37:33,799 - INFO - downloader - skip downloading file 000017.jpg
# 2020-09-12 10:37:33,800 - INFO - downloader - skip downloading file 000018.jpg
# 2020-09-12 10:37:33,801 - INFO - downloader - skip downloading file 000019.jpg
# 2020-09-12 10:37:33,802 - INFO - downloader - skip downloading file 000020.jpg
# 2020-09-12 10:37:33,804 - INFO - downloader - skip downloading file 000021.jpg
# 2020-09-12 10:37:33,806 - INFO - downloader - skip downloading file 000022.jpg
# 2020-09-12 10:37:33,807 - INFO - downloader - skip downloading file 000023.jpg
# 2020-09-12 10:37:33,810 - INFO - downloader - skip downloading file 000024.jpg
# 2020-09-12 10:37:33,810 - INFO - downloader - skip downloading file 000025.jpg
# 2020-09-12 10:37:33,811 - INFO - downloader - skip downloading file 000026.jpg
# 2020-09-12 10:37:33,813 - INFO - downloader - skip downloading file 000027.jpg
# 2020-09-12 10:37:33,814 - INFO - downloader - skip downloading file 000028.jpg
# 2020-09-12 10:37:33,815 - INFO - downloader - skip downloading file 000029.jpg
# 2020-09-12 10:37:33,819 - INFO - downloader - skip downloading file 000030.jpg
# 2020-09-12 10:37:33,820 - INFO - downloader - skip downloading file 000031.jpg
# 2020-09-12 10:37:33,821 - INFO - downloader - skip downloading file 000032.jpg
# 2020-09-12 10:37:33,822 - INFO - downloader - skip downloading file 000033.jpg
# 2020-09-12 10:37:33,822 - INFO - downloader - skip downloading file 000034.jpg
# 2020-09-12 10:37:33,824 - INFO - downloader - skip downloading file 000035.jpg
# 2020-09-12 10:37:34,016 - INFO - parser - parsing result page https://www.bing.com/images/async?q=猫&first=20
# 2020-09-12 10:37:34,031 - INFO - downloader - skip downloading file 000036.jpg
# 2020-09-12 10:37:34,032 - INFO - downloader - skip downloading file 000037.jpg
# 2020-09-12 10:37:34,033 - INFO - downloader - skip downloading file 000038.jpg
# 2020-09-12 10:37:34,034 - INFO - downloader - skip downloading file 000039.jpg
# 2020-09-12 10:37:34,036 - INFO - downloader - skip downloading file 000040.jpg
# 2020-09-12 10:37:34,037 - INFO - downloader - skip downloading file 000041.jpg
# 2020-09-12 10:37:34,040 - INFO - downloader - skip downloading file 000042.jpg
# 2020-09-12 10:37:34,042 - INFO - downloader - skip downloading file 000043.jpg
# 2020-09-12 10:37:34,043 - INFO - downloader - skip downloading file 000044.jpg
# 2020-09-12 10:37:34,044 - INFO - downloader - skip downloading file 000045.jpg
# 2020-09-12 10:37:34,047 - INFO - downloader - skip downloading file 000046.jpg
# 2020-09-12 10:37:34,048 - INFO - downloader - skip downloading file 000047.jpg
# 2020-09-12 10:37:34,049 - INFO - downloader - skip downloading file 000048.jpg
# 2020-09-12 10:37:34,050 - INFO - downloader - skip downloading file 000049.jpg
# 2020-09-12 10:37:34,051 - INFO - downloader - skip downloading file 000050.jpg
# 2020-09-12 10:37:34,248 - INFO - parser - parsing result page https://www.bing.com/images/async?q=猫&first=40
# 2020-09-12 10:37:34,264 - INFO - downloader - skip downloading file 000051.jpg
# 2020-09-12 10:37:34,265 - INFO - downloader - skip downloading file 000052.jpg
# 2020-09-12 10:37:34,266 - INFO - downloader - skip downloading file 000053.jpg
# 2020-09-12 10:37:34,268 - INFO - downloader - skip downloading file 000054.jpg
# 2020-09-12 10:37:34,269 - INFO - downloader - skip downloading file 000055.jpg
# 2020-09-12 10:37:34,271 - INFO - downloader - skip downloading file 000056.jpg
# 2020-09-12 10:37:34,272 - INFO - downloader - skip downloading file 000057.jpg
# 2020-09-12 10:37:34,273 - INFO - downloader - skip downloading file 000058.jpg
# 2020-09-12 10:37:34,274 - INFO - downloader - skip downloading file 000059.jpg
# 2020-09-12 10:37:34,275 - INFO - downloader - skip downloading file 000060.jpg
# 2020-09-12 10:37:34,276 - INFO - downloader - skip downloading file 000061.jpg
# 2020-09-12 10:37:34,278 - INFO - downloader - skip downloading file 000062.jpg
# 2020-09-12 10:37:34,281 - INFO - downloader - skip downloading file 000063.jpg
# 2020-09-12 10:37:34,282 - INFO - downloader - skip downloading file 000064.jpg
# 2020-09-12 10:37:34,283 - INFO - downloader - skip downloading file 000065.jpg
# 2020-09-12 10:37:34,284 - INFO - downloader - skip downloading file 000066.jpg
# 2020-09-12 10:37:34,285 - INFO - downloader - skip downloading file 000067.jpg
# 2020-09-12 10:37:34,465 - INFO - parser - parsing result page https://www.bing.com/images/async?q=猫&first=60
# 2020-09-12 10:37:34,482 - INFO - downloader - skip downloading file 000068.jpg
# 2020-09-12 10:37:34,483 - INFO - downloader - skip downloading file 000069.jpg
# 2020-09-12 10:37:34,484 - INFO - downloader - skip downloading file 000070.jpg
# 2020-09-12 10:37:34,485 - INFO - downloader - skip downloading file 000071.jpg
# 2020-09-12 10:37:34,486 - INFO - downloader - skip downloading file 000072.jpg
# 2020-09-12 10:37:34,488 - INFO - downloader - skip downloading file 000073.jpg
# 2020-09-12 10:37:34,491 - INFO - downloader - skip downloading file 000074.jpg
# 2020-09-12 10:37:34,492 - INFO - downloader - skip downloading file 000075.jpg
# 2020-09-12 10:37:34,493 - INFO - downloader - skip downloading file 000076.jpg
# 2020-09-12 10:37:34,495 - INFO - downloader - skip downloading file 000077.jpg
# 2020-09-12 10:37:34,497 - INFO - downloader - skip downloading file 000078.jpg
# 2020-09-12 10:37:34,498 - INFO - downloader - skip downloading file 000079.jpg
# 2020-09-12 10:37:34,498 - INFO - downloader - skip downloading file 000080.jpg
# 2020-09-12 10:37:34,499 - INFO - downloader - skip downloading file 000081.jpg
# 2020-09-12 10:37:34,500 - INFO - downloader - skip downloading file 000082.jpg
# 2020-09-12 10:37:34,697 - INFO - parser - parsing result page https://www.bing.com/images/async?q=猫&first=80
# 2020-09-12 10:37:34,712 - INFO - downloader - skip downloading file 000083.jpg
# 2020-09-12 10:37:34,713 - INFO - downloader - skip downloading file 000084.jpg
# 2020-09-12 10:37:34,714 - INFO - downloader - skip downloading file 000085.jpg
# 2020-09-12 10:37:34,715 - INFO - downloader - skip downloading file 000086.jpg
# 2020-09-12 10:37:34,717 - INFO - downloader - skip downloading file 000087.jpg
# 2020-09-12 10:37:34,718 - INFO - downloader - skip downloading file 000088.jpg
# 2020-09-12 10:37:34,719 - INFO - downloader - skip downloading file 000089.jpg
# 2020-09-12 10:37:34,721 - INFO - downloader - skip downloading file 000090.jpg
# 2020-09-12 10:37:34,724 - INFO - downloader - skip downloading file 000091.jpg
# 2020-09-12 10:37:34,725 - INFO - downloader - skip downloading file 000092.jpg
# 2020-09-12 10:37:34,726 - INFO - downloader - skip downloading file 000093.jpg
# 2020-09-12 10:37:34,727 - INFO - downloader - skip downloading file 000094.jpg
# 2020-09-12 10:37:36,719 - INFO - parser - no more page urls for thread parser-001 to parse
# 2020-09-12 10:37:36,720 - INFO - parser - thread parser-001 exit
# 2020-09-12 10:37:39,728 - INFO - downloader - no more download task for thread downloader-001
# 2020-09-12 10:37:39,729 - INFO - downloader - thread downloader-001 exit
# 2020-09-12 10:37:40,515 - INFO - icrawler.crawler - Crawling task done!
# 2020-09-12 10:37:40,518 - INFO - icrawler.crawler - start crawling...
# 2020-09-12 10:37:40,519 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-09-12 10:37:40,520 - INFO - feeder - thread feeder-001 exit
# 2020-09-12 10:37:40,521 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-09-12 10:37:40,535 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-09-12 10:37:40,822 - INFO - parser - parsing result page https://www.bing.com/images/async?q=犬&first=0
# 2020-09-12 10:37:40,840 - INFO - downloader - skip downloading file 000001.jpg
# 2020-09-12 10:37:40,842 - INFO - downloader - skip downloading file 000002.jpg
# 2020-09-12 10:37:40,843 - INFO - downloader - skip downloading file 000003.jpg
# 2020-09-12 10:37:40,844 - INFO - downloader - skip downloading file 000004.jpg
# 2020-09-12 10:37:40,845 - INFO - downloader - skip downloading file 000005.jpg
# 2020-09-12 10:37:40,847 - INFO - downloader - skip downloading file 000006.jpg
# 2020-09-12 10:37:40,848 - INFO - downloader - skip downloading file 000007.jpg
# 2020-09-12 10:37:40,849 - INFO - downloader - skip downloading file 000008.jpg
# 2020-09-12 10:37:40,851 - INFO - downloader - skip downloading file 000009.jpg
# 2020-09-12 10:37:40,852 - INFO - downloader - skip downloading file 000010.jpg
# 2020-09-12 10:37:40,853 - INFO - downloader - skip downloading file 000011.jpg
# 2020-09-12 10:37:40,854 - INFO - downloader - skip downloading file 000012.jpg
# 2020-09-12 10:37:40,855 - INFO - downloader - skip downloading file 000013.jpg
# 2020-09-12 10:37:40,856 - INFO - downloader - skip downloading file 000014.jpg
# 2020-09-12 10:37:40,858 - INFO - downloader - skip downloading file 000015.jpg
# 2020-09-12 10:37:40,859 - INFO - downloader - skip downloading file 000016.jpg
# 2020-09-12 10:37:40,861 - INFO - downloader - skip downloading file 000017.jpg
# 2020-09-12 10:37:40,862 - INFO - downloader - skip downloading file 000018.jpg
# 2020-09-12 10:37:40,866 - INFO - downloader - skip downloading file 000019.jpg
# 2020-09-12 10:37:40,870 - INFO - downloader - skip downloading file 000020.jpg
# 2020-09-12 10:37:40,872 - INFO - downloader - skip downloading file 000021.jpg
# 2020-09-12 10:37:40,873 - INFO - downloader - skip downloading file 000022.jpg
# 2020-09-12 10:37:40,874 - INFO - downloader - skip downloading file 000023.jpg
# 2020-09-12 10:37:40,875 - INFO - downloader - skip downloading file 000024.jpg
# 2020-09-12 10:37:40,877 - INFO - downloader - skip downloading file 000025.jpg
# 2020-09-12 10:37:40,878 - INFO - downloader - skip downloading file 000026.jpg
# 2020-09-12 10:37:40,883 - INFO - downloader - skip downloading file 000027.jpg
# 2020-09-12 10:37:40,884 - INFO - downloader - skip downloading file 000028.jpg
# 2020-09-12 10:37:40,885 - INFO - downloader - skip downloading file 000029.jpg
# 2020-09-12 10:37:40,886 - INFO - downloader - skip downloading file 000030.jpg
# 2020-09-12 10:37:40,887 - INFO - downloader - skip downloading file 000031.jpg
# 2020-09-12 10:37:40,888 - INFO - downloader - skip downloading file 000032.jpg
# 2020-09-12 10:37:41,075 - INFO - parser - parsing result page https://www.bing.com/images/async?q=犬&first=20
# 2020-09-12 10:37:41,091 - INFO - downloader - skip downloading file 000033.jpg
# 2020-09-12 10:37:41,092 - INFO - downloader - skip downloading file 000034.jpg
# 2020-09-12 10:37:41,093 - INFO - downloader - skip downloading file 000035.jpg
# 2020-09-12 10:37:41,093 - INFO - downloader - skip downloading file 000036.jpg
# 2020-09-12 10:37:41,095 - INFO - downloader - skip downloading file 000037.jpg
# 2020-09-12 10:37:41,096 - INFO - downloader - skip downloading file 000038.jpg
# 2020-09-12 10:37:41,098 - INFO - downloader - skip downloading file 000039.jpg
# 2020-09-12 10:37:41,099 - INFO - downloader - skip downloading file 000040.jpg
# 2020-09-12 10:37:41,101 - INFO - downloader - skip downloading file 000041.jpg
# 2020-09-12 10:37:41,102 - INFO - downloader - skip downloading file 000042.jpg
# 2020-09-12 10:37:41,103 - INFO - downloader - skip downloading file 000043.jpg
# 2020-09-12 10:37:41,105 - INFO - downloader - skip downloading file 000044.jpg
# 2020-09-12 10:37:41,106 - INFO - downloader - skip downloading file 000045.jpg
# 2020-09-12 10:37:41,109 - INFO - downloader - skip downloading file 000046.jpg
# 2020-09-12 10:37:41,110 - INFO - downloader - skip downloading file 000047.jpg
# 2020-09-12 10:37:41,111 - INFO - downloader - skip downloading file 000048.jpg
# 2020-09-12 10:37:41,111 - INFO - downloader - skip downloading file 000049.jpg
# 2020-09-12 10:37:41,112 - INFO - downloader - skip downloading file 000050.jpg
# 2020-09-12 10:37:41,311 - INFO - parser - parsing result page https://www.bing.com/images/async?q=犬&first=40
# 2020-09-12 10:37:41,326 - INFO - downloader - skip downloading file 000051.jpg
# 2020-09-12 10:37:41,326 - INFO - downloader - skip downloading file 000052.jpg
# 2020-09-12 10:37:41,327 - INFO - downloader - skip downloading file 000053.jpg
# 2020-09-12 10:37:41,328 - INFO - downloader - skip downloading file 000054.jpg
# 2020-09-12 10:37:41,330 - INFO - downloader - skip downloading file 000055.jpg
# 2020-09-12 10:37:41,331 - INFO - downloader - skip downloading file 000056.jpg
# 2020-09-12 10:37:41,333 - INFO - downloader - skip downloading file 000057.jpg
# 2020-09-12 10:37:41,334 - INFO - downloader - skip downloading file 000058.jpg
# 2020-09-12 10:37:41,335 - INFO - downloader - skip downloading file 000059.jpg
# 2020-09-12 10:37:41,336 - INFO - downloader - skip downloading file 000060.jpg
# 2020-09-12 10:37:41,338 - INFO - downloader - skip downloading file 000061.jpg
# 2020-09-12 10:37:41,339 - INFO - downloader - skip downloading file 000062.jpg
# 2020-09-12 10:37:41,340 - INFO - downloader - skip downloading file 000063.jpg
# 2020-09-12 10:37:41,341 - INFO - downloader - skip downloading file 000064.jpg
# 2020-09-12 10:37:41,342 - INFO - downloader - skip downloading file 000065.jpg
# 2020-09-12 10:37:41,546 - INFO - parser - parsing result page https://www.bing.com/images/async?q=犬&first=60
# 2020-09-12 10:37:41,572 - INFO - downloader - skip downloading file 000066.jpg
# 2020-09-12 10:37:41,573 - INFO - downloader - skip downloading file 000067.jpg
# 2020-09-12 10:37:41,575 - INFO - downloader - skip downloading file 000068.jpg
# 2020-09-12 10:37:41,579 - INFO - downloader - skip downloading file 000069.jpg
# 2020-09-12 10:37:41,580 - INFO - downloader - skip downloading file 000070.jpg
# 2020-09-12 10:37:41,581 - INFO - downloader - skip downloading file 000071.jpg
# 2020-09-12 10:37:41,582 - INFO - downloader - skip downloading file 000072.jpg
# 2020-09-12 10:37:41,583 - INFO - downloader - skip downloading file 000073.jpg
# 2020-09-12 10:37:41,585 - INFO - downloader - skip downloading file 000074.jpg
# 2020-09-12 10:37:41,586 - INFO - downloader - skip downloading file 000075.jpg
# 2020-09-12 10:37:41,587 - INFO - downloader - skip downloading file 000076.jpg
# 2020-09-12 10:37:41,590 - INFO - downloader - skip downloading file 000077.jpg
# 2020-09-12 10:37:41,592 - INFO - downloader - skip downloading file 000078.jpg
# 2020-09-12 10:37:41,592 - INFO - downloader - skip downloading file 000079.jpg
# 2020-09-12 10:37:41,594 - INFO - downloader - skip downloading file 000080.jpg
# 2020-09-12 10:37:41,787 - INFO - parser - parsing result page https://www.bing.com/images/async?q=犬&first=80
# 2020-09-12 10:37:41,802 - INFO - downloader - skip downloading file 000081.jpg
# 2020-09-12 10:37:41,803 - INFO - downloader - skip downloading file 000082.jpg
# 2020-09-12 10:37:41,804 - INFO - downloader - skip downloading file 000083.jpg
# 2020-09-12 10:37:41,807 - INFO - downloader - skip downloading file 000084.jpg
# 2020-09-12 10:37:41,808 - INFO - downloader - skip downloading file 000085.jpg
# 2020-09-12 10:37:41,809 - INFO - downloader - skip downloading file 000086.jpg
# 2020-09-12 10:37:41,811 - INFO - downloader - skip downloading file 000087.jpg
# 2020-09-12 10:37:41,812 - INFO - downloader - skip downloading file 000088.jpg
# 2020-09-12 10:37:41,813 - INFO - downloader - skip downloading file 000089.jpg
# 2020-09-12 10:37:41,814 - INFO - downloader - skip downloading file 000090.jpg
# 2020-09-12 10:37:41,815 - INFO - downloader - skip downloading file 000091.jpg
# 2020-09-12 10:37:41,816 - INFO - downloader - skip downloading file 000092.jpg
# 2020-09-12 10:37:41,819 - INFO - downloader - skip downloading file 000093.jpg
# 2020-09-12 10:37:41,820 - INFO - downloader - skip downloading file 000094.jpg
# 2020-09-12 10:37:41,821 - INFO - downloader - skip downloading file 000095.jpg
# 2020-09-12 10:37:41,822 - INFO - downloader - skip downloading file 000096.jpg
# 2020-09-12 10:37:43,815 - INFO - parser - no more page urls for thread parser-001 to parse
# 2020-09-12 10:37:43,816 - INFO - parser - thread parser-001 exit
# 2020-09-12 10:37:46,823 - INFO - downloader - no more download task for thread downloader-001
# 2020-09-12 10:37:46,824 - INFO - downloader - thread downloader-001 exit
# 2020-09-12 10:37:47,546 - INFO - icrawler.crawler - Crawling task done!
# Epoch 1/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.6776 - accuracy: 0.5616
# Epoch 2/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.6411 - accuracy: 0.6351
# Epoch 3/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.6075 - accuracy: 0.6809
# Epoch 4/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.5661 - accuracy: 0.7232
# Epoch 5/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.5286 - accuracy: 0.7416
# Epoch 6/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.4875 - accuracy: 0.7702
# Epoch 7/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.4556 - accuracy: 0.7980
# Epoch 8/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.4165 - accuracy: 0.8085
# Epoch 9/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.3898 - accuracy: 0.8187
# Epoch 10/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.3567 - accuracy: 0.8495
# Epoch 11/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.3228 - accuracy: 0.8631
# Epoch 12/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.2915 - accuracy: 0.8864
# Epoch 13/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.2666 - accuracy: 0.8948
# Epoch 14/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.2385 - accuracy: 0.9146
# Epoch 15/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.2245 - accuracy: 0.9137
# Epoch 16/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.1984 - accuracy: 0.9274
# Epoch 17/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.1666 - accuracy: 0.9406
# Epoch 18/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.1564 - accuracy: 0.9472
# Epoch 19/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.1348 - accuracy: 0.9582
# Epoch 20/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.1137 - accuracy: 0.9674
# Epoch 21/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.1001 - accuracy: 0.9710
# Epoch 22/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0861 - accuracy: 0.9798
# Epoch 23/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0798 - accuracy: 0.9762
# Epoch 24/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0647 - accuracy: 0.9820
# Epoch 25/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0597 - accuracy: 0.9842
# Epoch 26/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0533 - accuracy: 0.9846
# Epoch 27/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0456 - accuracy: 0.9886
# Epoch 28/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0407 - accuracy: 0.9912
# Epoch 29/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0348 - accuracy: 0.9921
# Epoch 30/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0279 - accuracy: 0.9934
# Epoch 31/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0318 - accuracy: 0.9908
# Epoch 32/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0218 - accuracy: 0.9943
# Epoch 33/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0193 - accuracy: 0.9960
# Epoch 34/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0141 - accuracy: 0.9978
# Epoch 35/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0164 - accuracy: 0.9960
# Epoch 36/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0153 - accuracy: 0.9969
# Epoch 37/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0166 - accuracy: 0.9956
# Epoch 38/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0115 - accuracy: 0.9982
# Epoch 39/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0092 - accuracy: 0.9978
# Epoch 40/40
# 82/82 [==============================] - 1s 12ms/step - loss: 0.0108 - accuracy: 0.9969
# [[0.0018972  0.99810284]]
# >>> 猫

# %% [markdown]
# # 新しいセクション
