# %% [markdown]
# <a href="https://colab.research.google.com/github/216d0136/python_practice/blob/master/lesson33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data = [2, 4, 6, 3, 5, 8, 4, 5]
plt.plot(data)
plt.show()
plt.plot([1,2,3,4],[1,5,10,15],"b--")
plt.show()

# %matplotlib inline
import matplotlib.pyplot as plt
data = [2, 4, 6, 3, 5, 8, 4, 5]
plt.plot(data)
plt.show()

# r--は赤の点線 b--は青の点線 g-- は緑の点線
plt.plot([1,2,3,4],[1,5,10,15],"r--") # 引数にオプションを渡さずに 色 に -- をつけると色 + 点線で表現できます
plt.show()


# %matplotlib inline 
import matplotlib.pyplot as plt
data = [20, 40, 60, 80 ]
y_data = [12, 5, 3, 1]
plt.xlabel("x")
plt.ylabel("y")
plt.plot(data, y_data, marker="o")
plt.savefig("graph.png")
plt.show()
